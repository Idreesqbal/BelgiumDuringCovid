# %%
# Importing Libraries
import pandas as pd
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
virus = pd.read_csv('COVID19BE_CASES_AGESEX.csv')

# %%
virus
# Out:
#              DATE        PROVINCE    REGION AGEGROUP  SEX  CASES
# 0      2020-03-01       Antwerpen  Flanders    40-49    M      1
# 1      2020-03-01        Brussels  Brussels    10-19    F      1
# 2      2020-03-01        Brussels  Brussels    10-19    M      1
# 3      2020-03-01        Brussels  Brussels    20-29    M      1
# 4      2020-03-01        Brussels  Brussels    30-39    F      1
# ...           ...             ...       ...      ...  ...    ...
# 36784         NaN   VlaamsBrabant  Flanders    40-49    M      3
# 36785         NaN   VlaamsBrabant  Flanders    50-59    M      1
# 36786         NaN  WestVlaanderen  Flanders    20-29    F      1
# 36787         NaN  WestVlaanderen  Flanders    50-59    M      3
# 36788         NaN             NaN       NaN      NaN  NaN      1
#
# [36789 rows x 6 columns]

# %%
virus = virus[['PROVINCE','CASES']]
virus
# Out:
#              PROVINCE  CASES
# 0           Antwerpen      1
# 1            Brussels      1
# 2            Brussels      1
# 3            Brussels      1
# 4            Brussels      1
# ...               ...    ...
# 36784   VlaamsBrabant      3
# 36785   VlaamsBrabant      1
# 36786  WestVlaanderen      1
# 36787  WestVlaanderen      3
# 36788             NaN      1
#
# [36789 rows x 2 columns]

# %%
belgium = gpd.read_file('zip://BELGIUM_-_Provinces-shp.zip') #gpd = geopandas

# %%
belgium
# Out:
#     OBJECTID CodeINS           NAME_2  FIRST_NAME  \
# 0          1   10000        Antwerpen  Vlaanderen
# 1          2    4000        Bruxelles   Bruxelles
# 2          3   20001   Vlaams Brabant  Vlaanderen
# 3          4   20002   Brabant Wallon    Wallonie
# 4          5   30000  West-Vlaanderen  Vlaanderen
# 5          6   40000  Oost-Vlaanderen  Vlaanderen
# 6          7   50000          Hainaut    Wallonie
# 7          8   60000            Liège    Wallonie
# 8          9   70000          Limburg  Vlaanderen
# 9         10   80000       Luxembourg    Wallonie
# 10        11   90000            Namur    Wallonie
#
#                                            FIRST_VARN      FIRST_ENGT  \
# 0            Amberes|Antuérpia|Antwerp|Anvers|Anversa        Province
# 1   Brussel Hoofstadt|Brusselse Hoofdstedelijke Ge...  Capital Region
# 2   Brabant Flamand|Brabante Flamenco|Brabante Fla...        Province
# 3        Waals Brabant|Walloon Brabant|Brabante Val?o        Province
# ...

# %%
belgium = belgium[['NE_Name','geometry']]

# %%
belgium.head()
# Out:
#            NE_Name                                           geometry
# 0        Antwerpen  MULTIPOLYGON (((4.94209 51.45524, 4.94062 51.4...
# 1          Brussel  POLYGON ((4.40633 50.91309, 4.40722 50.91295, ...
# 2   Vlaams Brabant  POLYGON ((3.98787 50.68749, 3.98772 50.68749, ...
# 3    Waals Brabant  POLYGON ((4.75386 50.80639, 4.75387 50.80639, ...
# 4  West-Vlaanderen  MULTIPOLYGON (((2.65679 51.12932, 2.65663 51.1...

# %%
belgium.plot()

# %%
belgium.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 11 entries, 0 to 10
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   NE_Name   11 non-null     object
#  1   geometry  11 non-null     geometry
# dtypes: geometry(1), object(1)
# memory usage: 304.0+ bytes

# %%
virus.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36789 entries, 0 to 36788
# Data columns (total 2 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   PROVINCE  34522 non-null  object
#  1   CASES     36789 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 575.0+ KB

# %%
belgium
# Out:
#             NE_Name                                           geometry
# 0         Antwerpen  MULTIPOLYGON (((4.94209 51.45524, 4.94062 51.4...
# 1           Brussel  POLYGON ((4.40633 50.91309, 4.40722 50.91295, ...
# 2    Vlaams Brabant  POLYGON ((3.98787 50.68749, 3.98772 50.68749, ...
# 3     Waals Brabant  POLYGON ((4.75386 50.80639, 4.75387 50.80639, ...
# 4   West-Vlaanderen  MULTIPOLYGON (((2.65679 51.12932, 2.65663 51.1...
# 5   Oost-Vlaanderen  POLYGON ((4.31166 51.29250, 4.31431 51.29112, ...
# 6        Henegouwen  MULTIPOLYGON (((3.71031 50.78190, 3.71065 50.7...
# 7              Luik  POLYGON ((6.13338 50.12956, 6.13309 50.12968, ...
# 8           Limburg  MULTIPOLYGON (((5.77703 50.78285, 5.77662 50.7...
# 9         Luxemburg  POLYGON ((5.43891 50.42170, 5.43908 50.42165, ...
# 10            Namen  POLYGON ((4.97055 50.64532, 4.97142 50.64479, ...

# %%
virus.groupby('PROVINCE').sum()
# Out:
#                 CASES
# PROVINCE
# Antwerpen       57427
# BrabantWallon   20364
# Brussels        68844
# Hainaut         77993
# Limburg         20316
# Liège           81589
# Luxembourg      13505
# Namur           27735
# OostVlaanderen  43367
# VlaamsBrabant   38635
# WestVlaanderen  36293

# %%
virus.groupby('PROVINCE').sum().T # T = Transpose
# Out:
# PROVINCE  Antwerpen  BrabantWallon  Brussels  Hainaut  Limburg  Liège  \
# CASES         57427          20364     68844    77993    20316  81589
#
# PROVINCE  Luxembourg  Namur  OostVlaanderen  VlaamsBrabant  WestVlaanderen
# CASES          13505  27735           43367          38635           36293

# %%
belgium['CASES'] = ['57427','68844','38635','20364','36293','43367','77993','81589','20481','13505','27735']
# Out:
# C:\Users\Idree\anaconda39\lib\site-packages\geopandas\geodataframe.py:853: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   super(GeoDataFrame, self).__setitem__(key, value)

# %%
belgium
# Out:
#             NE_Name                                           geometry  CASES
# 0         Antwerpen  MULTIPOLYGON (((4.94209 51.45524, 4.94062 51.4...  57427
# 1           Brussel  POLYGON ((4.40633 50.91309, 4.40722 50.91295, ...  68844
# 2    Vlaams Brabant  POLYGON ((3.98787 50.68749, 3.98772 50.68749, ...  38635
# 3     Waals Brabant  POLYGON ((4.75386 50.80639, 4.75387 50.80639, ...  20364
# 4   West-Vlaanderen  MULTIPOLYGON (((2.65679 51.12932, 2.65663 51.1...  36293
# 5   Oost-Vlaanderen  POLYGON ((4.31166 51.29250, 4.31431 51.29112, ...  43367
# 6        Henegouwen  MULTIPOLYGON (((3.71031 50.78190, 3.71065 50.7...  77993
# 7              Luik  POLYGON ((6.13338 50.12956, 6.13309 50.12968, ...  81589
# 8           Limburg  MULTIPOLYGON (((5.77703 50.78285, 5.77662 50.7...  20481
# 9         Luxemburg  POLYGON ((5.43891 50.42170, 5.43908 50.42165, ...  13505
# 10            Namen  POLYGON ((4.97055 50.64532, 4.97142 50.64479, ...  27735

# %%
belgium.plot(column='CASES',cmap='OrRd', legend=True,figsize=(12,20),label='PROVINCE')
